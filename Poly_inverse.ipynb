# %%
import jax
import jax.numpy as jnp
from jax import grad, jit
import optax 
import matplotlib.pyplot as plt
import numpy as np
from functools import partial
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import OrthogonalMatchingPursuit



seed = 45
key = jax.random.PRNGKey(seed)


# Parameters
n_agents = 14
n_steps = 20
true_theta_coefficients = jnp.array([-0.1, 0, 0, 0.1, 0, 0])
# parameters gamma (describes the x - discrepancy), tau, nu
true_Omega_parameters = jnp.array([4, 0.75, 5])
T = 1

K_channels = n_agents # can be changed to test the effect of media - type controls. In this project always equal to n_agents
t = jnp.linspace(0, T, n_steps)  # Time grid
dt = t[1] - t[0]

@jit
def func(x, u, theta):
    """
    Compute the forces acting on each particle given their positions, parameters (theta = (alpha, c)), and control values.

    Args:
        positions (list of float): A list of length N representing the positions of the particles at time t.
        theta (float of len 6): Parameters for the polynomial kernel.
        controls (list of float): A list of length N representing the control values at time t.

    Returns:
        list of float: A list of length N representing the forces acting on each particle at time t.
    """
    n = len(x)
    x_mean = jnp.mean(x)

    # Vectorized operations
    x_sq = x ** 2
    x_cube = x ** 3

    xi_part = (theta[0] + theta[1] * x + theta[3] * x_sq) * n * (x_mean - x)
    x_sq_sum = jnp.sum(x_sq)
    x_cube_sum = jnp.sum(x_cube)

    xj_part = (
        theta[2] * x * (n * x_mean - x_sq_sum) +
        theta[4] * (x * x_sq_sum - x_cube_sum) +
        theta[5] * (x_sq * jnp.sum(x) - x * x_sq_sum)
    )

    dynamics_part = xi_part + xj_part
    return dynamics_part + u

@jit
def rk4_step(x, u, dt, theta_coefficients):
    """Computes the next positions of the particles using the Runge-Kutta 4th order method

    Args:
        x (list of float): A list of length N representing the positions of the particles at time t.
        u (list of float): A list of length N representing the control values at time t.
        dt (float): time step
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        (list of float): A list of length N representing the positions of the particles at time t + dt.
    """
    k1 = dt * func(x, u, theta_coefficients)
    k2 = dt * func(x + 0.5 * k1, u, theta_coefficients)
    k3 = dt * func(x + 0.5 * k2, u, theta_coefficients)
    k4 = dt * func(x + k3, u, theta_coefficients)
    return x + (k1 + 2*k2 + 2*k3 + k4) / 6

@jit
def forward_pass(x_0, u_grid, theta_coefficients):
    """Computes the positions of the particles at each time step using the Runge-Kutta 4th order method

    Args:
        x_0 (float of len N): initial postinions of the particles
        u_grid (float of dim N x (K+1)): control values at each time step and for each particle
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        x_grid (float of dim N x (K+1)): positions of the particles at each time step
    """
    x_grid = jnp.zeros((n_agents, n_steps))
    x_grid = x_grid.at[:, 0].set(x_0)
    for i in range(1, n_steps):
        x = x_grid[:, i-1]
        u = u_grid[:, i-1]
        x_grid = x_grid.at[:, i].set(rk4_step(x, u, dt, theta_coefficients))
    return x_grid

def compute_J(x_grid, u_grid, theta_coefficients, Omega_parameters):
    """Computes the cost function J_Omega for a given trajectory, and parameters Omega

    Args:
        x_grid (float of dim N x (K+1)): positions of the particles at each time step
        u_grid (float of dim N x (K+1)): control values at each time step and for each particle
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function

    Returns:
        float: the value of the cost functional J_Omega
    """
    # Rescale Omega parameters
    rescaled_Omega_parameters = jnp.array([10, 1, 10]) * Omega_parameters
    gamma, x_hat, nu = rescaled_Omega_parameters

    # Compute the running cost J
    x_means = jnp.mean(x_grid[:, :n_steps], axis=0)
    x_diffs = x_grid[:, :n_steps] - x_means
    u_squares = jnp.square(u_grid[:, :n_steps])

    running_j = dt * jnp.sum(gamma * jnp.sum(jnp.square(x_diffs), axis=0) + jnp.sum(u_squares, axis=0))

    # Handle the final step separately if needed
    x_final = x_grid[:, n_steps - 1]
    phi = nu * jnp.dot(x_final - x_hat, x_final - x_hat)

    # Compute the final cost J
    J = running_j + phi
    return J

@jit
def compute_loss(u, x_0, theta_coefficients, Omega_parameters):
    """calls on the forward pass and compute_J functions to compute the loss function

    Args:
        u (float vector): control values before reshaping into a matrix
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function

    Returns:
        float: the value of the cost functional J_Omega
    """
    u_grid = u.reshape((K_channels, n_steps))
    x_grid = forward_pass(x_0, u_grid, theta_coefficients)
    return compute_J(x_grid, u_grid, theta_coefficients, Omega_parameters)

def run_optimization(x_0, theta_coefficients, Omega_parameters):
    """finds the optimal control signal u

    Args:
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function J

    Returns:
        u (float vector): control values before reshaping into a matrix
    """
    optimizer = optax.adam(learning_rate=0.05)
    gradient_u = lambda u: grad(compute_loss, argnums=0)(u, x_0, theta_coefficients, Omega_parameters)

    @partial(jit, static_argnums=(2,))
    def update_step(u, opt_state, n_agents):
        grads = gradient_u(u)
        updates, opt_state = optimizer.update(grads, opt_state)
        u = optax.apply_updates(u, updates)
        return u, opt_state

    u_init = jnp.zeros(K_channels * n_steps)
    opt_state = optimizer.init(u_init)
    u = u_init
    last_loss_values = []
    for i in range(50):  # Number of optimization steps
        u, opt_state = update_step(u, opt_state, n_agents)
        if i > 40:  # check convergence
            last_loss_values.append(compute_loss(u, x_0, theta_coefficients, Omega_parameters))

    have_converged = (max(last_loss_values) - min(last_loss_values)) / min(last_loss_values)
    while have_converged > 0.001:
        last_loss_values = []
        for i in range(20):  # Number of optimization steps
            u, opt_state = update_step(u, opt_state, n_agents)
            if i > 15:  # check convergence
                last_loss_values.append(compute_loss(u, x_0, theta_coefficients, Omega_parameters))
        have_converged = (max(last_loss_values) - min(last_loss_values)) / min(last_loss_values)
    return u

def find_u_grid(n_agents, n_steps, dt, x0, theta_coefficients, Omega_parameters):
    """calls on the run_optimization function to find the optimal control signal u, and reshapes it into a matrix

    Args:
        n_agents (int): N in the report, numer of agents
        n_steps (int): K in the reprt, number of time steps
        dt (float): time step
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function J

    Returns:
        N x (K+1) matrix of float: control values at each time step and for each particle
    """
    K_channels = n_agents
    u = run_optimization(x0, theta_coefficients, Omega_parameters)
    u_grid = u.reshape((K_channels, n_steps))
    return u_grid

#### helper functions for plotting ####
def plot_x(x_grid, n_agents, t, title=None):
    fig, ax = plt.subplots(figsize=(12, 6))
    for i in range(n_agents):
        ax.plot(t, x_grid[i], label=f'Agent {i+1}', linewidth=1.5)
    ax.set_xlabel('Time [s]', fontsize=12)
    ax.set_ylabel('State $x^{obs}$', fontsize=12)
    if title:
        ax.set_title(title, fontsize=14)
    ax.legend(loc='best', fontsize=10)
    ax.grid(True)
    plt.tight_layout()
    plt.show()

def plot_u(u_grid, K_channels, t, title=None):
    fig, ax = plt.subplots(figsize=(12, 6))
    for i in range(K_channels):
        ax.plot(t, u_grid[i], label=f'Channel {i+1}', linewidth=1.5)
    ax.set_xlabel('Time [s]', fontsize=12)
    ax.set_ylabel('Control Signal', fontsize=12)
    if title:
        ax.set_title(title, fontsize=14)
    ax.legend(loc='best', fontsize=10)
    ax.grid(True)
    plt.tight_layout()
    plt.show()

def plot_the_trajectories(u, x_0, theta, dt, n_agents, n_steps, t, scaled_Omega_parameters):
    K_channels = n_agents
    u_grid = u.reshape((K_channels, n_steps))
    x_grid = forward_pass(x_0, u_grid, theta)

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    fig.suptitle(
        f'Control Signals and State Trajectories\n'
        f'Theta Coefficients: {[f"{param:.3f}" for param in theta]}\n'
        f'Scaled Omega Parameters: {scaled_Omega_parameters}\n'
        f'Omega Parameters: {jnp.array([10,1,10]) * scaled_Omega_parameters}',
        fontsize=16
    )

    for j in range(n_agents):
        axes[0].plot(t, u_grid[j], label=f'Agent {j + 1}', linewidth=1.5)
        axes[1].plot(t, x_grid[j], label=f'Agent {j + 1}', linewidth=1.5)

    axes[0].set_title("Control Signals", fontsize=14)
    axes[0].set_xlabel('Time [s]', fontsize=12)
    axes[0].set_ylabel('Control Signal', fontsize=12)
    axes[0].grid(True)

    axes[1].set_title("State Trajectories", fontsize=14)
    axes[1].set_xlabel('Time [s]', fontsize=12)
    axes[1].set_ylabel('State $x^{obs}$', fontsize=12)
    axes[1].grid(True)

    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower center', ncol=n_agents, fontsize=10)
    plt.tight_layout(rect=[0, 0.05, 1, 0.95])
    plt.show()




key, subkey = jax.random.split(key)
x0 = jax.random.uniform(subkey, (n_agents,), minval=-1, maxval=1)


scaled_Omega_parameters = jnp.array([0.1, 1, 0.1]) * true_Omega_parameters
u_observed = find_u_grid(n_agents, n_steps, dt, x0, true_theta_coefficients, scaled_Omega_parameters)
x_observed = forward_pass(x0, u_observed, true_theta_coefficients)

plot_the_trajectories(u_observed, x0, true_theta_coefficients, dt, n_agents, n_steps, t, scaled_Omega_parameters)

# %%
def find_coefficients_l0(x, u, n_nonzero_coefs):
    """ finds a sparse representation of the coefficients of the polynomial kernel using Lasso regression

        Args:
            x (float of dim N x (K+1)): observed positions of the particles at each time step
            u (float of dim N x (K+1)): observed control values at each time step and for each particle
            lasso_regularization (float): coefficient for the Lasso regularization

        Returns:
            (float of len 6): the coefficients of the polynomial kernel
    """


    # Estimate the derivatives using central difference method
    x_prime = np.zeros_like(x)
    # Central difference for interior points, forward/backward difference for boundaries
    for i in range(n_agents):
        x_prime[i, 1:-1] = (x[i, 2:] - x[i, :-2]) / (2 * dt)
        x_prime[i, 0] = (x[i, 1] - x[i, 0]) / dt
        x_prime[i, -1] = (x[i, -1] - x[i, -2]) / dt

    X = []
    Y = []
    for k in range(n_steps):
        for i in range(n_agents):
            row = np.zeros(6)
            for j in range(n_agents):
                row += np.array([1, x[i, k], x[j, k], x[i, k]**2, x[j, k]**2, x[i, k]*x[j, k]]) * (x[j, k] - x[i, k])
            X.append(row)
            Y.append(x_prime[i, k] - u[i, k])

    X = np.array(X)
    Y = np.array(Y)

    omp = OrthogonalMatchingPursuit(n_nonzero_coefs=n_nonzero_coefs)
    omp.fit(X, Y)

    return omp.coef_

# Estimate the coefficients of the polynomial kernel for sparsity level 2
estimated_theta = find_coefficients_l0(x_observed, u_observed, n_nonzero_coefs=2)
print(estimated_theta)
# Out:
# [-0.08777736  0.          0.          0.08519279  0.          0.        ]

# %%
def discrepancy_of_optimal_controls_2(Omega_test, theta_coefficients):
    """implements the function E(Omega) as described in 4.1 for a polynomial kernel

    Args:
        Omega_test (flaot, float, float): parameters Omega of the loss function J
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        flaot: E_theta(Omega) = ||u_optimal_Omega - u_observed||^2 + ||x_optimal_Omega - x_observed||^2
    """
    
    u_optimal_Omega = find_u_grid(n_agents, n_steps, dt, x0, theta_coefficients, Omega_test)

    x_optimal_Omega = forward_pass(x0, u_optimal_Omega, theta_coefficients)

    if u_optimal_Omega is None:
        return 0.1

    return jnp.linalg.norm(u_optimal_Omega - u_observed, ord=2)**2 + jnp.linalg.norm(x_optimal_Omega - x_observed, ord=2)**2

def find_Omega_parameters(theta_coefficients):
    """Implement the optimization algorithm to find the Omega parameters with finite difference gradients

    Args:
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
    Returns:
        \hat{Omega} parameters (float, float, float): ; estimates for the Omega parameters
        Omega_trajectory (list of float): trajectory of the Omega parameters during the optimization
        control_discrepancies (list of float): control discrepancies at each iteration
    """
    # Initial guess of  gamma (for x consensus), tau, nu
    Omega_parameters = jnp.array([1.0, 0.0, 1.0])

    # Define the optimizer
    learning_rate = 0.2
    optimizer = optax.adam(learning_rate=learning_rate, b1 = 0.9, b2 = 0.99)
    opt_state = optimizer.init(Omega_parameters)

    max_iter = 100
    h = 0.0001
    # discontinuity_threshold = 100000
    tol_for_convergence = 1e-6
    Omega_trajectory = []
    control_discrepancies = []

    for i in range(max_iter):

        mistake_from_observation = discrepancy_of_optimal_controls_2( Omega_parameters, theta_coefficients)
        Omega_trajectory.append(Omega_parameters)
        control_discrepancies.append(mistake_from_observation)

        print(f"Iteration: {i}, Parameters: { Omega_parameters}, Controls discrepancy: {mistake_from_observation}")

        # Compute gradients using finite difference
        gradient_est = jnp.zeros_like(Omega_parameters)
        for grad_dire in range(Omega_parameters.size):
            para_plus_h = Omega_parameters.at[grad_dire].add(h)
            new_value = (discrepancy_of_optimal_controls_2(para_plus_h, theta_coefficients) - mistake_from_observation) / h
            gradient_est = gradient_est.at[grad_dire].set(new_value)

        print(f"Gradient estimation from the finite difference: {gradient_est}")

        if mistake_from_observation < tol_for_convergence * n_agents or jnp.linalg.norm(gradient_est) < tol_for_convergence:
            return Omega_parameters, Omega_trajectory, control_discrepancies

        #if jnp.linalg.norm(gradient_est) > discontinuity_threshold:
        #    print("Function discontinuous, gradient descent will break apart")
        #    break

        # Update parameters using Adam optimization rule
        updates, opt_state = optimizer.update(gradient_est, opt_state, Omega_parameters)
        Omega_parameters = optax.apply_updates(Omega_parameters, updates)

        # Ensure parameters stay within the domain
        Omega_parameters = Omega_parameters.at[0].set(jnp.maximum(0. + h, Omega_parameters[0]))
        Omega_parameters = Omega_parameters.at[1].set(jnp.maximum(-(1 - h), Omega_parameters[1]))
        Omega_parameters = Omega_parameters.at[1].set(jnp.minimum(1-h, Omega_parameters[1]))
        Omega_parameters = Omega_parameters.at[2].set(jnp.maximum(0. + h , Omega_parameters[2]))

    return Omega_parameters, Omega_trajectory, control_discrepancies


print(f"true Omega parameters: {true_Omega_parameters}")
print(f"scaled Omega parameters (what the function should return): {jnp.array([0.1, 1, 0.1]) * true_Omega_parameters}")
print(f"using the infered parameters {estimated_theta}")
Omega_parameters, Omega_trajectory, control_discrepancies = find_Omega_parameters(estimated_theta)
print(f"estimated Omega parameters [output of the function times scaling]: {jnp.array([10,1,10]) * Omega_parameters}")
# Out:
# true Omega parameters: [4.   0.75 5.  ]
# scaled Omega parameters (what the function should return): [0.4  0.75 0.5 ]
# using the infered parameters [-0.08777736  0.          0.          0.08519279  0.          0.        ]
# Iteration: 0, Parameters: [1. 0. 1.], Controls discrepancy: 149.39328002929688
# Gradient estimation from the finite difference: [   3.0517578 -422.97363     -1.2207031]
# Iteration: 1, Parameters: [0.80000013 0.19999987 1.1999998 ], Controls discrepancy: 75.455078125
# Gradient estimation from the finite difference: [   3.9672852 -304.8706      -4.119873 ]
# Iteration: 2, Parameters: [0.6004474  0.39588726 1.3804126 ], Controls discrepancy: 26.27234649658203
# Gradient estimation from the finite difference: [   3.5858154 -181.65588     -2.9754639]
# Iteration: 3, Parameters: [0.40065137 0.5812315  1.5677985 ], Controls discrepancy: 3.9490675926208496
# Gradient estimation from the finite difference: [ -2.8562546 -38.66434     1.680851 ]
# Iteration: 4, Parameters: [0.3010663 0.7411841 1.6785133], Controls discrepancy: 5.372081756591797
# Gradient estimation from the finite difference: [-20.647049   19.7649      3.8528442]
# Iteration: 5, Parameters: [0.37786525 0.87267375 1.6923143 ], Controls discrepancy: 15.088728904724121
# Gradient estimation from the finite difference: [ -0.30517578 133.3046       5.7697296 ]
# Iteration: 6, Parameters: [0.44565964 0.9582883  1.6334357 ], Controls discrepancy: 28.67752456665039
# Gradient estimation from the finite difference: [  1.3160706 192.01279     8.411407 ]
# Iteration: 7, Parameters: [0.49878237 0.99643505 1.5270039 ], Controls discrepancy: 35.51081085205078
# Gradient estimation from the finite difference: [  1.9073486 220.87097    10.4522705]
# Iteration: 8, Parameters: [0.5368806 0.9934494 1.3920153], Controls discrepancy: 33.4610710144043
# Gradient estimation from the finite difference: [  2.2506714 206.71844    11.711121 ]
# Iteration: 9, Parameters: [0.5605518 0.9606254 1.2383633], Controls discrepancy: 24.93248748779297
# Gradient estimation from the finite difference: [  0.22888184 176.06735     10.967255  ]
# Iteration: 10, Parameters: [0.5807104 0.9075142 1.0720634], Controls discrepancy: 14.961968421936035
# Gradient estimation from the finite difference: [  1.1730194 133.96263     9.946823 ]
# Iteration: 11, Parameters: [0.59360695 0.8422849  0.8972611 ], Controls discrepancy: 6.323886871337891
# Gradient estimation from the finite difference: [ 4.425049 82.559586  8.449554]
# Iteration: 12, Parameters: [0.5858159  0.77262694 0.71764135], Controls discrepancy: 1.6875447034835815
# Gradient estimation from the finite difference: [11.572838  19.148588   0.4541874]
# Iteration: 13, Parameters: [0.5352555  0.70707923 0.5537031 ], Controls discrepancy: 0.7409993410110474
# Gradient estimation from the finite difference: [  5.9723854 -12.232065   -5.1409006]
# Iteration: 14, Parameters: [0.46841994 0.6494245  0.42671692], Controls discrepancy: 4.331223487854004
# Gradient estimation from the finite difference: [  3.0231476 -61.540604  -21.2574   ]
# Iteration: 15, Parameters: [0.3969053  0.60587674 0.39740428], Controls discrepancy: 8.083864212036133
# Gradient estimation from the finite difference: [  2.2029877 -85.13451   -28.9917   ]
# Iteration: 16, Parameters: [0.3238942 0.5784529 0.4393807], Controls discrepancy: 9.25309944152832
# Gradient estimation from the finite difference: [  5.41687  -94.070435 -22.230148]
# Iteration: 17, Parameters: [0.23884988 0.56682557 0.5163677 ], Controls discrepancy: 8.520644187927246
# Gradient estimation from the finite difference: [  3.8433075 -91.581345  -15.172958 ]
# Iteration: 18, Parameters: [0.1480045  0.569096   0.61161745], Controls discrepancy: 11.934187889099121
# Gradient estimation from the finite difference: [-71.725845  -23.317337    5.7792664]
# Iteration: 19, Parameters: [0.21098815 0.57444966 0.6869939 ], Controls discrepancy: 8.599458694458008
# Gradient estimation from the finite difference: [-47.130585  -20.952225    6.9236755]
# Iteration: 20, Parameters: [0.3110534 0.582317  0.7420436], Controls discrepancy: 5.0241875648498535
# Gradient estimation from the finite difference: [  1.6927719 -75.23537    -6.008148 ]
# Iteration: 21, Parameters: [0.40042934 0.60025996 0.8032956 ], Controls discrepancy: 3.537182331085205
# Gradient estimation from the finite difference: [  2.4580956 -63.66253    -4.901886 ]
# Iteration: 22, Parameters: [0.4791941 0.6257928 0.8683034], Controls discrepancy: 2.0723135471343994
# Gradient estimation from the finite difference: [  2.3674965 -46.851635   -2.6845932]
# Iteration: 23, Parameters: [0.5483709  0.65591484 0.9327525 ], Controls discrepancy: 1.008880853652954
# Gradient estimation from the finite difference: [  2.2268295  -27.276278    -0.38862228]
# Iteration: 24, Parameters: [0.6089423  0.6874468  0.99234873], Controls discrepancy: 1.496068000793457
# Gradient estimation from the finite difference: [14.493465  -0.6425381 -2.3961067]
# Iteration: 25, Parameters: [0.64683235 0.7163339  1.0514733 ], Controls discrepancy: 2.0287609100341797
# Gradient estimation from the finite difference: [15.847683  6.709099 -1.707077]
# Iteration: 26, Parameters: [0.66268796 0.7416845  1.1088797 ], Controls discrepancy: 2.531336784362793
# Gradient estimation from the finite difference: [15.091896  19.555092  -0.3004074]
# Iteration: 27, Parameters: [0.6596293 0.7617898 1.1619203], Controls discrepancy: 3.0785818099975586
# Gradient estimation from the finite difference: [12.331009  36.77845    1.5258789]
# Iteration: 28, Parameters: [0.64262354 0.7743381  1.207169  ], Controls discrepancy: 3.5462393760681152
# Gradient estimation from the finite difference: [ 9.162426  50.90475    2.8038025]
# Iteration: 29, Parameters: [0.616491  0.7776627 1.2425275], Controls discrepancy: 3.6266584396362305
# Gradient estimation from the finite difference: [ 6.816387  57.189465   3.2782555]
# Iteration: 30, Parameters: [0.5846522  0.77148545 1.2677622 ], Controls discrepancy: 3.1686394214630127
# Gradient estimation from the finite difference: [ 5.197525  55.840015   3.2162666]
# Iteration: 31, Parameters: [0.549413   0.75677943 1.2838173 ], Controls discrepancy: 2.2924294471740723
# Gradient estimation from the finite difference: [ 3.8957596 48.139095   2.861023 ]
# Iteration: 32, Parameters: [0.512544   0.73546016 1.2921987 ], Controls discrepancy: 1.3026008605957031
# Gradient estimation from the finite difference: [ 2.5594234 35.40039    2.3937225]
# Iteration: 33, Parameters: [0.47574732 0.7101163  1.2945387 ], Controls discrepancy: 1.402343988418579
# Gradient estimation from the finite difference: [-3.1483173 12.542009   3.6239624]
# Iteration: 34, Parameters: [0.44609252 0.68485844 1.2885448 ], Controls discrepancy: 1.3634681701660156
# Gradient estimation from the finite difference: [-6.2322617  1.552105   3.2305717]
# Iteration: 35, Parameters: [0.42694062 0.66153276 1.275753  ], Controls discrepancy: 1.5021623373031616
# Gradient estimation from the finite difference: [-7.072687  -5.6767464  2.976656 ]
# Iteration: 36, Parameters: [0.41852593 0.64122874 1.2572587 ], Controls discrepancy: 1.6936718225479126
# Gradient estimation from the finite difference: [ -6.0355663 -13.084412    2.604723 ]
# Iteration: 37, Parameters: [0.41864485 0.6250095  1.2343414 ], Controls discrepancy: 1.9320778846740723
# Gradient estimation from the finite difference: [ -2.95043   -23.698807    1.8560886]
# Iteration: 38, Parameters: [0.42260838 0.61445594 1.2090656 ], Controls discrepancy: 2.198272466659546
# Gradient estimation from the finite difference: [ -0.03576279 -34.780502     0.93460083]
# Iteration: 39, Parameters: [0.4262725  0.61113757 1.1837717 ], Controls discrepancy: 2.3067121505737305
# Gradient estimation from the finite difference: [  1.0681152  -39.78014      0.46253204]
# Iteration: 40, Parameters: [0.428181   0.61540365 1.1595744 ], Controls discrepancy: 2.1318559646606445
# Gradient estimation from the finite difference: [  0.9584427  -37.884712     0.46730042]
# Iteration: 41, Parameters: [0.42861736 0.6263111  1.1363536 ], Controls discrepancy: 1.7440414428710938
# Gradient estimation from the finite difference: [ -0.16570091 -30.30777      0.9036064 ]
# Iteration: 42, Parameters: [0.42924395 0.641936   1.1129286 ], Controls discrepancy: 1.3243311643600464
# Gradient estimation from the finite difference: [ -2.1660328 -19.751787    1.61767  ]
# Iteration: 43, Parameters: [0.43284205 0.6599329  1.0875008 ], Controls discrepancy: 0.9933804273605347
# Gradient estimation from the finite difference: [ -3.7825108 -11.020899    2.116561 ]
# Iteration: 44, Parameters: [0.44146997 0.6784631  1.0589384 ], Controls discrepancy: 0.7467172145843506
# Gradient estimation from the finite difference: [-4.1258335 -4.506111   2.270341 ]
# Iteration: 45, Parameters: [0.45523196 0.6962362  1.0270674 ], Controls discrepancy: 0.5609988570213318
# Gradient estimation from the finite difference: [-3.5351515 -1.2797117  2.348423 ]
# Iteration: 46, Parameters: [0.47288683 0.712691   0.99191827], Controls discrepancy: 0.45390379428863525
# Gradient estimation from the finite difference: [-1.9469857  4.249513   2.5236607]
# Iteration: 47, Parameters: [0.4918297 0.7268386 0.9532637], Controls discrepancy: 0.47486865520477295
# Gradient estimation from the finite difference: [ 1.8659234 15.41406    2.5731325]
# Iteration: 48, Parameters: [0.5063188 0.7366061 0.9112203], Controls discrepancy: 0.6034842729568481
# Gradient estimation from the finite difference: [ 3.900528  20.403862   2.0116568]
# Iteration: 49, Parameters: [0.51365066 0.74131995 0.86751336], Controls discrepancy: 0.6524145007133484
# Gradient estimation from the finite difference: [ 4.783869  19.894838   1.5836954]
# Iteration: 50, Parameters: [0.5130604  0.74148715 0.82338905], Controls discrepancy: 0.5965704321861267
# Gradient estimation from the finite difference: [ 5.3572655 16.347767   0.9548664]
# Iteration: 51, Parameters: [0.50431263 0.7382096  0.7805621 ], Controls discrepancy: 0.4799273610115051
# Gradient estimation from the finite difference: [ 5.404353   11.236966    0.21189451]
# Iteration: 52, Parameters: [0.48799658 0.7328393  0.7409612 ], Controls discrepancy: 0.35509902238845825
# Gradient estimation from the finite difference: [ 4.6360493   6.2704086  -0.36358833]
# Iteration: 53, Parameters: [0.4659108  0.7266018  0.70592654], Controls discrepancy: 0.261078804731369
# Gradient estimation from the finite difference: [ 3.117621   2.2390485 -0.603497 ]
# Iteration: 54, Parameters: [0.44088477 0.7204353  0.6757555 ], Controls discrepancy: 0.21931138634681702
# Gradient estimation from the finite difference: [ 1.4990568  -0.89004636 -0.6209314 ]
# Iteration: 55, Parameters: [0.4157056 0.7150166 0.6500871], Controls discrepancy: 0.47102978825569153
# Gradient estimation from the finite difference: [-4.8571825 -3.8143992  2.0301342]
# Iteration: 56, Parameters: [0.4006674  0.71093196 0.62079966], Controls discrepancy: 0.5129421353340149
# Gradient estimation from the finite difference: [-5.4115057 -5.1802397  1.6546249]
# Iteration: 57, Parameters: [0.39582756 0.7083792  0.5892628 ], Controls discrepancy: 0.513928234577179
# Gradient estimation from the finite difference: [-4.5126677 -7.594824   0.7933378]
# Iteration: 58, Parameters: [0.39885435 0.70778334 0.55819076], Controls discrepancy: 0.5092785358428955
# Gradient estimation from the finite difference: [ -2.2244453 -12.025237   -0.9441376]
# Iteration: 59, Parameters: [0.40530708 0.71000606 0.5327764 ], Controls discrepancy: 0.5172906517982483
# Gradient estimation from the finite difference: [ -0.4386902 -15.736818   -2.8139353]
# Iteration: 60, Parameters: [0.41191608 0.71568453 0.5182857 ], Controls discrepancy: 0.4727323651313782
# Gradient estimation from the finite difference: [  0.08612871 -15.185178    -3.3417344 ]
# Iteration: 61, Parameters: [0.41778266 0.7244149  0.51541936], Controls discrepancy: 0.3671054542064667
# Gradient estimation from the finite difference: [ -0.21010637 -10.795296    -2.4211407 ]
# Iteration: 62, Parameters: [0.42348054 0.7349175  0.5203326 ], Controls discrepancy: 0.2740817666053772
# Gradient estimation from the finite difference: [-0.936985   -4.900694   -0.95784664]
# Iteration: 63, Parameters: [0.43028992 0.74564594 0.5278055 ], Controls discrepancy: 0.23750846087932587
# Gradient estimation from the finite difference: [-1.1752546  -0.04082918 -0.07793307]
# Iteration: 64, Parameters: [0.4385444  0.75541353 0.53484935], Controls discrepancy: 0.2511204481124878
# Gradient estimation from the finite difference: [-0.64104795  4.44144     0.3990531 ]
# Iteration: 65, Parameters: [0.44718736 0.7632084  0.5399766 ], Controls discrepancy: 0.30507662892341614
# Gradient estimation from the finite difference: [0.42647123 9.090304   0.95903873]
# Iteration: 66, Parameters: [0.45428273 0.7680465  0.54153466], Controls discrepancy: 0.36436596512794495
# Gradient estimation from the finite difference: [ 1.2603402 12.19064    1.4853477]
# Iteration: 67, Parameters: [0.458453   0.76939803 0.53809786], Controls discrepancy: 0.3820314109325409
# Gradient estimation from the finite difference: [ 1.7097592 12.565554   1.5571713]
# Iteration: 68, Parameters: [0.4591194 0.7674553 0.5298398], Controls discrepancy: 0.3499641716480255
# Gradient estimation from the finite difference: [ 1.8647313 10.439456   1.103878 ]
# Iteration: 69, Parameters: [0.45628452 0.7630288  0.5186593 ], Controls discrepancy: 0.29882439970970154
# Gradient estimation from the finite difference: [1.7848611  6.8333745  0.34958124]
# Iteration: 70, Parameters: [0.45038328 0.7572467  0.50732106], Controls discrepancy: 0.26221728324890137
# Gradient estimation from the finite difference: [ 1.514554    2.8559566  -0.46879053]
# Iteration: 71, Parameters: [0.44217184 0.751249   0.49860853], Controls discrepancy: 0.25223541259765625
# Gradient estimation from the finite difference: [ 1.1086464 -0.615716  -1.1494756]
# Iteration: 72, Parameters: [0.43260443 0.7459599  0.49463406], Controls discrepancy: 0.2592240571975708
# Gradient estimation from the finite difference: [ 0.5450845 -2.8812885 -1.4686584]
# Iteration: 73, Parameters: [0.42286515 0.74191713 0.49610513], Controls discrepancy: 0.27120018005371094
# Gradient estimation from the finite difference: [-0.3400445 -4.3591857 -1.4594197]
# Iteration: 74, Parameters: [0.41467386 0.73941016 0.50253505], Controls discrepancy: 0.2808033525943756
# Gradient estimation from the finite difference: [-1.3151765 -3.9979815 -0.9313226]
# Iteration: 75, Parameters: [0.40980265 0.7382123  0.5116566 ], Controls discrepancy: 0.2880347669124603
# Gradient estimation from the finite difference: [-2.2509694 -3.039837  -0.3284216]
# Iteration: 76, Parameters: [0.40981752 0.7379529  0.52111125], Controls discrepancy: 0.28726887702941895
# Gradient estimation from the finite difference: [-2.6926398  -2.3195148   0.01996756]
# Iteration: 77, Parameters: [0.4151865 0.7383556 0.5296286], Controls discrepancy: 0.2730109393596649
# Gradient estimation from the finite difference: [-2.477169   -1.9314885   0.10997057]
# Iteration: 78, Parameters: [0.42503065 0.7392579  0.53696704], Controls discrepancy: 0.25074708461761475
# Gradient estimation from the finite difference: [-1.7827749  -1.6978383  -0.00506639]
# Iteration: 79, Parameters: [0.43757814 0.7405534  0.5436511 ], Controls discrepancy: 0.23139996826648712
# Gradient estimation from the finite difference: [-0.8483231 -1.3975799 -0.2297759]
# Iteration: 80, Parameters: [0.45070618 0.7421254  0.5505695 ], Controls discrepancy: 0.22281403839588165
# Gradient estimation from the finite difference: [ 0.18313527 -0.602752   -0.44211745]
# Iteration: 81, Parameters: [0.4622512 0.7437251 0.5584981], Controls discrepancy: 0.2268606722354889
# Gradient estimation from the finite difference: [ 1.2607872   0.8022785  -0.55491924]
# Iteration: 82, Parameters: [0.47011206 0.7449468  0.5677817 ], Controls discrepancy: 0.23699617385864258
# Gradient estimation from the finite difference: [ 2.117008    2.4409592  -0.48667192]
# Iteration: 83, Parameters: [0.47280753 0.7453467  0.57805514], Controls discrepancy: 0.2401067614555359
# Gradient estimation from the finite difference: [ 2.348423   3.6641955 -0.3041327]
# Iteration: 84, Parameters: [0.47028795 0.7446356  0.5885457 ], Controls discrepancy: 0.22994111478328705
# Gradient estimation from the finite difference: [ 1.7365813   3.8316846  -0.14945865]
# Iteration: 85, Parameters: [0.46429783 0.7428567  0.5986466 ], Controls discrepancy: 0.2176886349916458
# Gradient estimation from the finite difference: [0.24065375 2.3047626  0.0448525 ]
# Iteration: 86, Parameters: [0.45834196 0.74055415 0.60764235], Controls discrepancy: 0.2200334221124649
# Gradient estimation from the finite difference: [-1.1783838   0.41171908  0.48026443]
# Iteration: 87, Parameters: [0.45549238 0.73833996 0.61392385], Controls discrepancy: 0.22846627235412598
# Gradient estimation from the finite difference: [-1.7261505  -0.48920512  0.79885125]
# Iteration: 88, Parameters: [0.45668238 0.7364785  0.61646396], Controls discrepancy: 0.22992749512195587
# Gradient estimation from the finite difference: [-1.7100573 -1.0377169  0.8314848]
# Iteration: 89, Parameters: [0.46153384 0.7351065  0.6154519 ], Controls discrepancy: 0.22374823689460754
# Gradient estimation from the finite difference: [-1.2879074  -1.6444921   0.59366226]
# Iteration: 90, Parameters: [0.4688007  0.7343689  0.61214507], Controls discrepancy: 0.21716970205307007
# Gradient estimation from the finite difference: [-0.5351007  -1.9954145   0.15422702]
# Iteration: 91, Parameters: [0.47659588 0.7343207  0.6085182 ], Controls discrepancy: 0.2177290916442871
# Gradient estimation from the finite difference: [ 0.6714463 -1.2895465 -0.3786385]
# Iteration: 92, Parameters: [0.4821517  0.7346817  0.60677564], Controls discrepancy: 0.22560954093933105
# Gradient estimation from the finite difference: [ 1.9860268   0.07197261 -0.67800283]
# Iteration: 93, Parameters: [0.4826649  0.7349866  0.60799074], Controls discrepancy: 0.2259107530117035
# Gradient estimation from the finite difference: [ 2.1484494  0.4467368 -0.6645918]
# Iteration: 94, Parameters: [0.47819564 0.73512065 0.6118563 ], Controls discrepancy: 0.21690680086612701
# Gradient estimation from the finite difference: [ 0.95024705 -0.5342066  -0.40203333]
# Iteration: 95, Parameters: [0.47194025 0.7354142  0.6170488 ], Controls discrepancy: 0.21455788612365723
# Gradient estimation from the finite difference: [-0.4169345  -1.4172494   0.14781952]
# Iteration: 96, Parameters: [0.4672378 0.7361403 0.6211356], Controls discrepancy: 0.21870069205760956
# Gradient estimation from the finite difference: [-1.103431  -1.2780726  0.57742  ]
# Iteration: 97, Parameters: [0.46556827 0.7372171  0.6223836 ], Controls discrepancy: 0.22033753991127014
# Gradient estimation from the finite difference: [-1.3023615  -0.88751316  0.70527196]
# Iteration: 98, Parameters: [0.46714258 0.7384867  0.6204878 ], Controls discrepancy: 0.21653850376605988
# Gradient estimation from the finite difference: [-1.0080636  -0.28803945  0.50246716]
# Iteration: 99, Parameters: [0.47098035 0.7397342  0.6165938 ], Controls discrepancy: 0.21391263604164124
# Gradient estimation from the finite difference: [0.09283423 1.2913346  0.05021691]
# estimated Omega parameters [output of the function times scaling]: [4.742382  0.7404333 6.1284213]

# %%
# plots the trajectory of the Omega parameters

# Convert trajectories and discrepancies to numpy arrays for plotting
Omega_trajectory = jnp.array(Omega_trajectory)
control_discrepancies = jnp.array(control_discrepancies)

# Plot the results
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot of the Omega parameters trajectory
sc = ax.scatter(Omega_trajectory[:, 0], Omega_trajectory[:, 1], Omega_trajectory[:, 2],
                c=control_discrepancies, cmap='viridis', marker='o')

# Plot the true Omega parameters
ax.scatter(scaled_Omega_parameters[0], scaled_Omega_parameters[1], scaled_Omega_parameters[2],
           color='red', marker='x', s=100, label='Scaled $\\Omega$ Parameters')

# Plot arrows and edges
for i in range(1, len(Omega_trajectory)):
    ax.plot([Omega_trajectory[i-1, 0], Omega_trajectory[i, 0]],
            [Omega_trajectory[i-1, 1], Omega_trajectory[i, 1]],
            [Omega_trajectory[i-1, 2], Omega_trajectory[i, 2]], 'gray')
    ax.quiver(Omega_trajectory[i-1, 0], Omega_trajectory[i-1, 1], Omega_trajectory[i-1, 2],
              Omega_trajectory[i, 0] - Omega_trajectory[i-1, 0],
              Omega_trajectory[i, 1] - Omega_trajectory[i-1, 1],
              Omega_trajectory[i, 2] - Omega_trajectory[i-1, 2], color='black', arrow_length_ratio=0.1)

ax.set_xlabel('$\\gamma$')
ax.set_ylabel('$\\tau$')
ax.set_zlabel('$\\nu$')
ax.set_title('Trajectory of $\\Omega$ Parameters')
fig.colorbar(sc, ax=ax, label='Discrepancy E')

# Adjust the legend position
ax.legend(loc='upper left', bbox_to_anchor=(0, 1))

plt.show()

# %%
# verify if the results at least look similar:
estimated_Omega_parameters = Omega_parameters
print(f"obtained parameters: {estimated_Omega_parameters}")

print(f"estimated theta: {estimated_theta}")

u_star = find_u_grid(n_agents, n_steps, dt, x0, estimated_theta, estimated_Omega_parameters)
print("optimized_trajectory: from learnt coefficints")
plot_the_trajectories(u_star, x0, estimated_theta, dt, n_agents, n_steps, t, estimated_Omega_parameters)


print("previously observed trajectory ")
print(f"true beta parameters: {true_Omega_parameters}")
plot_the_trajectories(u_observed, x0, true_theta_coefficients, dt, n_agents, n_steps, t, scaled_Omega_parameters)
# Out:
# obtained parameters: [0.4742382  0.7404333  0.61284214]
# estimated theta: [ 0.1006   0.       0.      -0.08932  0.       0.     ]
# optimized_trajectory: from learnt coefficints
# previously observed trajectory
# true beta parameters: [4.   0.75 5.  ]
