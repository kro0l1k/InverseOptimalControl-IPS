# %%
import jax
import jax.numpy as jnp
from jax import grad, jit
import optax 
import matplotlib.pyplot as plt
import numpy as np
from functools import partial
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import OrthogonalMatchingPursuit



seed = 45
key = jax.random.PRNGKey(seed)


# Parameters
n_agents = 14
n_steps = 20
true_theta_coefficients = jnp.array([-0.1, 0, 0, 0.1, 0, 0])
# parameters gamma (describes the x - discrepancy), tau, nu
true_Omega_parameters = jnp.array([4, 0.75, 5])
T = 1

K_channels = n_agents # can be changed to test the effect of media - type controls. In this project always equal to n_agents
t = jnp.linspace(0, T, n_steps)  # Time grid
dt = t[1] - t[0]

@jit
def func(x, u, theta):
    """
    Compute the forces acting on each particle given their positions, parameters (theta = (alpha, c)), and control values.

    Args:
        positions (list of float): A list of length N representing the positions of the particles at time t.
        theta (float of len 6): Parameters for the polynomial kernel.
        controls (list of float): A list of length N representing the control values at time t.

    Returns:
        list of float: A list of length N representing the forces acting on each particle at time t.
    """
    n = len(x)
    x_mean = jnp.mean(x)

    # Vectorized operations
    x_sq = x ** 2
    x_cube = x ** 3

    xi_part = (theta[0] + theta[1] * x + theta[3] * x_sq) * n * (x_mean - x)
    x_sq_sum = jnp.sum(x_sq)
    x_cube_sum = jnp.sum(x_cube)

    xj_part = (
        theta[2] * x * (n * x_mean - x_sq_sum) +
        theta[4] * (x * x_sq_sum - x_cube_sum) +
        theta[5] * (x_sq * jnp.sum(x) - x * x_sq_sum)
    )

    dynamics_part = xi_part + xj_part
    return dynamics_part + u

@jit
def rk4_step(x, u, dt, theta_coefficients):
    """Computes the next positions of the particles using the Runge-Kutta 4th order method

    Args:
        x (list of float): A list of length N representing the positions of the particles at time t.
        u (list of float): A list of length N representing the control values at time t.
        dt (float): time step
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        (list of float): A list of length N representing the positions of the particles at time t + dt.
    """
    k1 = dt * func(x, u, theta_coefficients)
    k2 = dt * func(x + 0.5 * k1, u, theta_coefficients)
    k3 = dt * func(x + 0.5 * k2, u, theta_coefficients)
    k4 = dt * func(x + k3, u, theta_coefficients)
    return x + (k1 + 2*k2 + 2*k3 + k4) / 6

@jit
def forward_pass(x_0, u_grid, theta_coefficients):
    """Computes the positions of the particles at each time step using the Runge-Kutta 4th order method

    Args:
        x_0 (float of len N): initial postinions of the particles
        u_grid (float of dim N x (K+1)): control values at each time step and for each particle
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        x_grid (float of dim N x (K+1)): positions of the particles at each time step
    """
    x_grid = jnp.zeros((n_agents, n_steps))
    x_grid = x_grid.at[:, 0].set(x_0)
    for i in range(1, n_steps):
        x = x_grid[:, i-1]
        u = u_grid[:, i-1]
        x_grid = x_grid.at[:, i].set(rk4_step(x, u, dt, theta_coefficients))
    return x_grid

def compute_J(x_grid, u_grid, theta_coefficients, Omega_parameters):
    """Computes the cost function J_Omega for a given trajectory, and parameters Omega

    Args:
        x_grid (float of dim N x (K+1)): positions of the particles at each time step
        u_grid (float of dim N x (K+1)): control values at each time step and for each particle
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function

    Returns:
        float: the value of the cost functional J_Omega
    """
    # Rescale Omega parameters
    rescaled_Omega_parameters = jnp.array([10, 1, 10]) * Omega_parameters
    gamma, x_hat, nu = rescaled_Omega_parameters

    # Compute the running cost J
    x_means = jnp.mean(x_grid[:, :n_steps], axis=0)
    x_diffs = x_grid[:, :n_steps] - x_means
    u_squares = jnp.square(u_grid[:, :n_steps])

    running_j = dt * jnp.sum(gamma * jnp.sum(jnp.square(x_diffs), axis=0) + jnp.sum(u_squares, axis=0))

    # Handle the final step separately if needed
    x_final = x_grid[:, n_steps - 1]
    phi = nu * jnp.dot(x_final - x_hat, x_final - x_hat)

    # Compute the final cost J
    J = running_j + phi
    return J

@jit
def compute_loss(u, x_0, theta_coefficients, Omega_parameters):
    """calls on the forward pass and compute_J functions to compute the loss function

    Args:
        u (float vector): control values before reshaping into a matrix
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function

    Returns:
        float: the value of the cost functional J_Omega
    """
    u_grid = u.reshape((K_channels, n_steps))
    x_grid = forward_pass(x_0, u_grid, theta_coefficients)
    return compute_J(x_grid, u_grid, theta_coefficients, Omega_parameters)

def run_optimization(x_0, theta_coefficients, Omega_parameters):
    """finds the optimal control signal u

    Args:
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function J

    Returns:
        u (float vector): control values before reshaping into a matrix
    """
    optimizer = optax.adam(learning_rate=0.05)
    gradient_u = lambda u: grad(compute_loss, argnums=0)(u, x_0, theta_coefficients, Omega_parameters)

    @partial(jit, static_argnums=(2,))
    def update_step(u, opt_state, n_agents):
        grads = gradient_u(u)
        updates, opt_state = optimizer.update(grads, opt_state)
        u = optax.apply_updates(u, updates)
        return u, opt_state

    u_init = jnp.zeros(K_channels * n_steps)
    opt_state = optimizer.init(u_init)
    u = u_init
    last_loss_values = []
    for i in range(50):  # Number of optimization steps
        u, opt_state = update_step(u, opt_state, n_agents)
        if i > 40:  # check convergence
            last_loss_values.append(compute_loss(u, x_0, theta_coefficients, Omega_parameters))

    have_converged = (max(last_loss_values) - min(last_loss_values)) / min(last_loss_values)
    while have_converged > 0.001:
        last_loss_values = []
        for i in range(20):  # Number of optimization steps
            u, opt_state = update_step(u, opt_state, n_agents)
            if i > 15:  # check convergence
                last_loss_values.append(compute_loss(u, x_0, theta_coefficients, Omega_parameters))
        have_converged = (max(last_loss_values) - min(last_loss_values)) / min(last_loss_values)
    return u

def find_u_grid(n_agents, n_steps, dt, x0, theta_coefficients, Omega_parameters):
    """calls on the run_optimization function to find the optimal control signal u, and reshapes it into a matrix

    Args:
        n_agents (int): N in the report, numer of agents
        n_steps (int): K in the reprt, number of time steps
        dt (float): time step
        x_0 (float of len N): initial postinions of the particles
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
        Omega_parameters (float, float, float): scaled down parameters of the loss function J

    Returns:
        N x (K+1) matrix of float: control values at each time step and for each particle
    """
    K_channels = n_agents
    u = run_optimization(x0, theta_coefficients, Omega_parameters)
    u_grid = u.reshape((K_channels, n_steps))
    return u_grid

#### helper functions for plotting ####
def plot_x(x_grid, n_agents, t, title=None):
    fig, ax = plt.subplots(figsize=(12, 6))
    for i in range(n_agents):
        ax.plot(t, x_grid[i], label=f'Agent {i+1}', linewidth=1.5)
    ax.set_xlabel('Time [s]', fontsize=12)
    ax.set_ylabel('State $x^{obs}$', fontsize=12)
    if title:
        ax.set_title(title, fontsize=14)
    ax.legend(loc='best', fontsize=10)
    ax.grid(True)
    plt.tight_layout()
    plt.show()

def plot_u(u_grid, K_channels, t, title=None):
    fig, ax = plt.subplots(figsize=(12, 6))
    for i in range(K_channels):
        ax.plot(t, u_grid[i], label=f'Channel {i+1}', linewidth=1.5)
    ax.set_xlabel('Time [s]', fontsize=12)
    ax.set_ylabel('Control Signal', fontsize=12)
    if title:
        ax.set_title(title, fontsize=14)
    ax.legend(loc='best', fontsize=10)
    ax.grid(True)
    plt.tight_layout()
    plt.show()

def plot_the_trajectories(u, x_0, theta, dt, n_agents, n_steps, t, scaled_Omega_parameters):
    K_channels = n_agents
    u_grid = u.reshape((K_channels, n_steps))
    x_grid = forward_pass(x_0, u_grid, theta)

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    fig.suptitle(
        f'Control Signals and State Trajectories\n'
        f'Theta Coefficients: {[f"{param:.3f}" for param in theta]}\n'
        f'Scaled Omega Parameters: {scaled_Omega_parameters}\n'
        f'Omega Parameters: {jnp.array([10,1,10]) * scaled_Omega_parameters}',
        fontsize=16
    )

    for j in range(n_agents):
        axes[0].plot(t, u_grid[j], label=f'Agent {j + 1}', linewidth=1.5)
        axes[1].plot(t, x_grid[j], label=f'Agent {j + 1}', linewidth=1.5)

    axes[0].set_title("Control Signals", fontsize=14)
    axes[0].set_xlabel('Time [s]', fontsize=12)
    axes[0].set_ylabel('Control Signal', fontsize=12)
    axes[0].grid(True)

    axes[1].set_title("State Trajectories", fontsize=14)
    axes[1].set_xlabel('Time [s]', fontsize=12)
    axes[1].set_ylabel('State $x^{obs}$', fontsize=12)
    axes[1].grid(True)

    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower center', ncol=n_agents, fontsize=10)
    plt.tight_layout(rect=[0, 0.05, 1, 0.95])
    plt.show()




key, subkey = jax.random.split(key)
x0 = jax.random.uniform(subkey, (n_agents,), minval=-1, maxval=1)


scaled_Omega_parameters = jnp.array([0.1, 1, 0.1]) * true_Omega_parameters
u_observed = find_u_grid(n_agents, n_steps, dt, x0, true_theta_coefficients, scaled_Omega_parameters)
x_observed = forward_pass(x0, u_observed, true_theta_coefficients)

plot_the_trajectories(u_observed, x0, true_theta_coefficients, dt, n_agents, n_steps, t, scaled_Omega_parameters)

# %%
def find_coefficients_l0(x, u, n_nonzero_coefs):
    """ finds a sparse representation of the coefficients of the polynomial kernel using OMP

        Args:
            x (float of dim N x (K+1)): observed positions of the particles at each time step
            u (float of dim N x (K+1)): observed control values at each time step and for each particle
            lasso_regularization (float): coefficient for the Lasso regularization

        Returns:
            (float of len 6): the coefficients of the polynomial kernel
    """


    # Estimate the derivatives using central difference method
    x_prime = np.zeros_like(x)
    # Central difference for interior points, forward/backward difference for boundaries
    for i in range(n_agents):
        x_prime[i, 1:-1] = (x[i, 2:] - x[i, :-2]) / (2 * dt)
        x_prime[i, 0] = (x[i, 1] - x[i, 0]) / dt
        x_prime[i, -1] = (x[i, -1] - x[i, -2]) / dt

    X = []
    Y = []
    for k in range(n_steps):
        for i in range(n_agents):
            row = np.zeros(6)
            for j in range(n_agents):
                row += np.array([1, x[i, k], x[j, k], x[i, k]**2, x[j, k]**2, x[i, k]*x[j, k]]) * (x[j, k] - x[i, k])
            X.append(row)
            Y.append(x_prime[i, k] - u[i, k])

    X = np.array(X)
    Y = np.array(Y)

    omp = OrthogonalMatchingPursuit(n_nonzero_coefs=n_nonzero_coefs)
    omp.fit(X, Y)

    return omp.coef_

# Estimate the coefficients of the polynomial kernel for sparsity level 2
estimated_theta = find_coefficients_l0(x_observed, u_observed, n_nonzero_coefs=2)
print(estimated_theta)
# Out:
# [-0.08777742  0.          0.          0.08519293  0.          0.        ]

# %%
def discrepancy_of_optimal_controls_2(Omega_test, theta_coefficients):
    """implements the function E(Omega) as described in 4.1 for a polynomial kernel

    Args:
        Omega_test (flaot, float, float): parameters Omega of the loss function J
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.

    Returns:
        flaot: E_theta(Omega) = ||u_optimal_Omega - u_observed||^2 + ||x_optimal_Omega - x_observed||^2
    """
    
    u_optimal_Omega = find_u_grid(n_agents, n_steps, dt, x0, theta_coefficients, Omega_test)

    x_optimal_Omega = forward_pass(x0, u_optimal_Omega, theta_coefficients)

    if u_optimal_Omega is None:
        return 0.1

    return jnp.linalg.norm(u_optimal_Omega - u_observed, ord=2)**2 + jnp.linalg.norm(x_optimal_Omega - x_observed, ord=2)**2

def find_Omega_parameters(theta_coefficients):
    """Implement the optimization algorithm to find the Omega parameters with finite difference gradients

    Args:
        theta_coefficients (float of len 6): Parameters for the polynomial kernel.
    Returns:
        \hat{Omega} parameters (float, float, float): ; estimates for the Omega parameters
        Omega_trajectory (list of float): trajectory of the Omega parameters during the optimization
        control_discrepancies (list of float): control discrepancies at each iteration
    """
    # Initial guess of  gamma (for x consensus), tau, nu
    Omega_parameters = jnp.array([1.0, 0.0, 1.0])

    # Define the optimizer
    learning_rate = 0.2
    optimizer = optax.adam(learning_rate=learning_rate, b1 = 0.9, b2 = 0.99)
    opt_state = optimizer.init(Omega_parameters)

    max_iter = 100
    h = 0.0001
    # discontinuity_threshold = 100000
    tol_for_convergence = 1e-6
    Omega_trajectory = []
    control_discrepancies = []

    for i in range(max_iter):

        mistake_from_observation = discrepancy_of_optimal_controls_2( Omega_parameters, theta_coefficients)
        Omega_trajectory.append(Omega_parameters)
        control_discrepancies.append(mistake_from_observation)

        print(f"Iteration: {i}, Parameters: { Omega_parameters}, Controls discrepancy: {mistake_from_observation}")

        # Compute gradients using finite difference
        gradient_est = jnp.zeros_like(Omega_parameters)
        for grad_dire in range(Omega_parameters.size):
            para_plus_h = Omega_parameters.at[grad_dire].add(h)
            new_value = (discrepancy_of_optimal_controls_2(para_plus_h, theta_coefficients) - mistake_from_observation) / h
            gradient_est = gradient_est.at[grad_dire].set(new_value)

        print(f"Gradient estimation from the finite difference: {gradient_est}")

        if mistake_from_observation < tol_for_convergence * n_agents or jnp.linalg.norm(gradient_est) < tol_for_convergence:
            return Omega_parameters, Omega_trajectory, control_discrepancies

        #if jnp.linalg.norm(gradient_est) > discontinuity_threshold:
        #    print("Function discontinuous, gradient descent will break apart")
        #    break

        # Update parameters using Adam optimization rule
        updates, opt_state = optimizer.update(gradient_est, opt_state, Omega_parameters)
        Omega_parameters = optax.apply_updates(Omega_parameters, updates)

        # Ensure parameters stay within the domain
        Omega_parameters = Omega_parameters.at[0].set(jnp.maximum(0. + h, Omega_parameters[0]))
        Omega_parameters = Omega_parameters.at[1].set(jnp.maximum(-(1 - h), Omega_parameters[1]))
        Omega_parameters = Omega_parameters.at[1].set(jnp.minimum(1-h, Omega_parameters[1]))
        Omega_parameters = Omega_parameters.at[2].set(jnp.maximum(0. + h , Omega_parameters[2]))

    return Omega_parameters, Omega_trajectory, control_discrepancies


print(f"true Omega parameters: {true_Omega_parameters}")
print(f"scaled Omega parameters (what the function should return): {jnp.array([0.1, 1, 0.1]) * true_Omega_parameters}")
print(f"using the infered parameters {estimated_theta}")
Omega_parameters, Omega_trajectory, control_discrepancies = find_Omega_parameters(estimated_theta)
print(f"estimated Omega parameters [output of the function times scaling]: {jnp.array([10,1,10]) * Omega_parameters}")
# Out:
# true Omega parameters: [4.   0.75 5.  ]
# scaled Omega parameters (what the function should return): [0.4  0.75 0.5 ]
# using the infered parameters [-0.08777742  0.          0.          0.08519293  0.          0.        ]
# Iteration: 0, Parameters: [1. 0. 1.], Controls discrepancy: 149.3932342529297
# Gradient estimation from the finite difference: [   2.89917    -422.36328      -0.76293945]
# Iteration: 1, Parameters: [0.80000013 0.19999987 1.1999998 ], Controls discrepancy: 75.45507049560547
# Gradient estimation from the finite difference: [   4.119873 -304.7943     -4.272461]
# Iteration: 2, Parameters: [0.6013229  0.39591074 1.3696985 ], Controls discrepancy: 26.303800582885742
# Gradient estimation from the finite difference: [   3.6239624 -181.82755     -3.1089783]
# Iteration: 3, Parameters: [0.40205294 0.5813152  1.5507137 ], Controls discrepancy: 3.9142212867736816
# Gradient estimation from the finite difference: [ -2.2172928 -40.044785    1.5974045]
# Iteration: 4, Parameters: [0.287323  0.7415858 1.6596423], Controls discrepancy: 5.608675003051758
# Gradient estimation from the finite difference: [-23.207664   17.504692    3.7956238]
# Iteration: 5, Parameters: [0.36521125 0.87381005 1.6742033 ], Controls discrepancy: 15.141897201538086
# Gradient estimation from the finite difference: [ -0.705719 133.73375    5.788803]
# Iteration: 6, Parameters: [0.43550268 0.9599227  1.6158985 ], Controls discrepancy: 28.835983276367188
# Gradient estimation from the finite difference: [  0.78201294 192.64221      8.392334  ]
# Iteration: 7, Parameters: [0.49372455 0.9983407  1.5099499 ], Controls discrepancy: 35.730430603027344
# Gradient estimation from the finite difference: [  1.7166138 214.65302    10.681152 ]
# Iteration: 8, Parameters: [0.53800243 0.9965403  1.3751645 ], Controls discrepancy: 33.90234375
# Gradient estimation from the finite difference: [  2.2125244 208.01544    12.130737 ]
# Iteration: 9, Parameters: [0.5683072 0.9644487 1.2215954], Controls discrepancy: 25.423114776611328
# Gradient estimation from the finite difference: [  0.4196167 178.3371     11.386871 ]
# Iteration: 10, Parameters: [0.59373003 0.91164136 1.0552398 ], Controls discrepancy: 15.363679885864258
# Gradient estimation from the finite difference: [  1.449585 135.33592   10.39505 ]
# Iteration: 11, Parameters: [0.6107362  0.8464915  0.88020116], Controls discrepancy: 6.6070756912231445
# Gradient estimation from the finite difference: [ 5.083084 83.413124  8.807182]
# Iteration: 12, Parameters: [0.6058553 0.7767869 0.7002149], Controls discrepancy: 2.01102614402771
# Gradient estimation from the finite difference: [13.332367   17.957687   -0.09775162]
# Iteration: 13, Parameters: [0.55631757 0.7113554  0.53792953], Controls discrepancy: 0.9451534748077393
# Gradient estimation from the finite difference: [ 9.272099  -7.6955557 -5.36263  ]
# Iteration: 14, Parameters: [0.48358825 0.65317434 0.4127372 ], Controls discrepancy: 4.459932327270508
# Gradient estimation from the finite difference: [  3.4713745 -61.011314  -23.031235 ]
# Iteration: 15, Parameters: [0.4067597  0.60908407 0.38834512], Controls discrepancy: 8.10324478149414
# Gradient estimation from the finite difference: [  2.412796 -84.3811   -30.33638 ]
# Iteration: 16, Parameters: [0.329292   0.5810765  0.43348926], Controls discrepancy: 9.169143676757812
# Gradient estimation from the finite difference: [  5.4836273 -93.43147   -22.773743 ]
# Iteration: 17, Parameters: [0.24222206 0.5688496  0.5124084 ], Controls discrepancy: 8.409355163574219
# Gradient estimation from the finite difference: [  3.900528 -90.83748  -15.34462 ]
# Iteration: 18, Parameters: [0.15092534 0.57049286 0.60870695], Controls discrepancy: 11.677337646484375
# Gradient estimation from the finite difference: [-70.54329   -22.945404    5.7792664]
# Iteration: 19, Parameters: [0.2082651  0.57522786 0.68550193], Controls discrepancy: 8.702322006225586
# Gradient estimation from the finite difference: [-48.0175    -20.780563    6.9904327]
# Iteration: 20, Parameters: [0.30436406 0.58251154 0.742255  ], Controls discrepancy: 4.997371196746826
# Gradient estimation from the finite difference: [  1.6021729 -75.068474   -6.0129166]
# Iteration: 21, Parameters: [0.39023727 0.5999178  0.8046483 ], Controls discrepancy: 3.5276923179626465
# Gradient estimation from the finite difference: [  2.3651123 -63.738823   -4.9233437]
# Iteration: 22, Parameters: [0.46593207 0.6249876  0.87039286], Controls discrepancy: 2.0732829570770264
# Gradient estimation from the finite difference: [  2.336502  -47.01376    -2.6655197]
# Iteration: 23, Parameters: [0.5323621 0.6547214 0.9352879], Controls discrepancy: 1.0064722299575806
# Gradient estimation from the finite difference: [  2.0360947 -27.611256   -0.4684925]
# Iteration: 24, Parameters: [0.59066516 0.6859542  0.9954127 ], Controls discrepancy: 0.8933428525924683
# Gradient estimation from the finite difference: [ 9.7543     -1.1759996   0.03695488]
# Iteration: 25, Parameters: [0.63234854 0.71464896 1.0502387 ], Controls discrepancy: 1.7959251403808594
# Gradient estimation from the finite difference: [15.052557   6.4218044 -1.5974045]
# Iteration: 26, Parameters: [0.6525438 0.7398665 1.1033876], Controls discrepancy: 2.34734845161438
# Gradient estimation from the finite difference: [14.62698   18.827915  -0.3027916]
# Iteration: 27, Parameters: [0.6538892 0.7599597 1.1525222], Controls discrepancy: 2.9281418323516846
# Gradient estimation from the finite difference: [12.226105  35.35509    1.4019012]
# Iteration: 28, Parameters: [0.6409447 0.7727141 1.194574 ], Controls discrepancy: 3.415170192718506
# Gradient estimation from the finite difference: [ 9.288788  49.114227   2.6726723]
# Iteration: 29, Parameters: [0.61832476 0.7764996  1.2275076 ], Controls discrepancy: 3.525373935699463
# Gradient estimation from the finite difference: [ 7.1167946 55.53484    3.1852722]
# Iteration: 30, Parameters: [0.58931327 0.7709911  1.2509842 ], Controls discrepancy: 3.112893581390381
# Gradient estimation from the finite difference: [ 5.5599213 54.631233   3.1590462]
# Iteration: 31, Parameters: [0.5562091 0.7570707 1.2658104], Controls discrepancy: 2.283355236053467
# Gradient estimation from the finite difference: [ 4.301071  47.442913   2.7799606]
# Iteration: 32, Parameters: [0.52079165 0.7365637  1.2734686 ], Controls discrepancy: 1.3208222389221191
# Gradient estimation from the finite difference: [ 3.0601025 35.47907    2.3078918]
# Iteration: 33, Parameters: [0.48470286 0.71193475 1.2755226 ], Controls discrepancy: 1.3329870700836182
# Gradient estimation from the finite difference: [-2.3400784 13.6220455  3.5953522]
# Iteration: 34, Parameters: [0.4546849 0.6871426 1.2696178], Controls discrepancy: 1.2565218210220337
# Gradient estimation from the finite difference: [-5.379915   1.8370152  3.1852722]
# Iteration: 35, Parameters: [0.43413123 0.66419256 1.2572634 ], Controls discrepancy: 1.385045051574707
# Gradient estimation from the finite difference: [-6.2692165 -5.5515766  2.8955936]
# Iteration: 36, Parameters: [0.42343378 0.64421165 1.239584  ], Controls discrepancy: 1.5811448097229004
# Gradient estimation from the finite difference: [ -5.5146217 -12.764931    2.5582314]
# Iteration: 37, Parameters: [0.4208273 0.6282356 1.2177227], Controls discrepancy: 1.8198158740997314
# Gradient estimation from the finite difference: [ -2.9361248 -22.581816    1.8811226]
# Iteration: 38, Parameters: [0.42230168 0.617712   1.1935045 ], Controls discrepancy: 2.0727851390838623
# Gradient estimation from the finite difference: [ -0.3170967 -32.89938     1.0156631]
# Iteration: 39, Parameters: [0.42406884 0.614093   1.1690667 ], Controls discrepancy: 2.182678699493408
# Gradient estimation from the finite difference: [  0.7748604 -37.9014      0.5221367]
# Iteration: 40, Parameters: [0.42463633 0.61775815 1.1455503 ], Controls discrepancy: 2.0346901416778564
# Gradient estimation from the finite difference: [  0.66041946 -36.32784      0.5221367 ]
# Iteration: 41, Parameters: [0.42425144 0.62784815 1.1228608 ], Controls discrepancy: 1.6870670318603516
# Gradient estimation from the finite difference: [ -0.47922134 -29.22535      0.94890594]
# Iteration: 42, Parameters: [0.42456412 0.6425409  1.09989   ], Controls discrepancy: 1.302304983139038
# Gradient estimation from the finite difference: [ -2.48909   -19.264221    1.6224384]
# Iteration: 43, Parameters: [0.4283412  0.65960574 1.0750057 ], Controls discrepancy: 0.9884548187255859
# Gradient estimation from the finite difference: [ -4.0072203 -11.078715    2.07901  ]
# Iteration: 44, Parameters: [0.4374713 0.6773032 1.0472159], Controls discrepancy: 0.7434201836585999
# Gradient estimation from the finite difference: [-4.245043  -5.722046   2.2351742]
# Iteration: 45, Parameters: [0.45188338 0.694557   1.0163362 ], Controls discrepancy: 0.5513139367103577
# Gradient estimation from the finite difference: [-3.516078  -2.129078   2.2417307]
# Iteration: 46, Parameters: [0.4701219  0.71070737 0.9825642 ], Controls discrepancy: 0.4298652410507202
# Gradient estimation from the finite difference: [-2.2000074  2.8437376  2.3570657]
# Iteration: 47, Parameters: [0.48997822 0.72485733 0.94580716], Controls discrepancy: 0.4242469072341919
# Gradient estimation from the finite difference: [ 1.6105175 13.45098    2.4992228]
# Iteration: 48, Parameters: [0.50567096 0.73501784 0.90590835], Controls discrepancy: 0.5593328475952148
# Gradient estimation from the finite difference: [ 4.0125847 19.120575   1.8399954]
# Iteration: 49, Parameters: [0.513907   0.74034184 0.8647777 ], Controls discrepancy: 0.6305017471313477
# Gradient estimation from the finite difference: [ 4.9096346 19.014479   1.4579296]
# Iteration: 50, Parameters: [0.513921  0.7412358 0.8234723], Controls discrepancy: 0.5972182154655457
# Gradient estimation from the finite difference: [ 5.4341555 16.118885   0.9173155]
# Iteration: 51, Parameters: [0.5055756  0.73865813 0.7834008 ], Controls discrepancy: 0.4925791621208191
# Gradient estimation from the finite difference: [ 5.452633   11.657775    0.26613474]
# Iteration: 52, Parameters: [0.48952192 0.73382866 0.74618304], Controls discrepancy: 0.36709609627723694
# Gradient estimation from the finite difference: [ 4.673898    7.0381165  -0.27120113]
# Iteration: 53, Parameters: [0.46759117 0.72791445 0.71303076], Controls discrepancy: 0.2658863067626953
# Gradient estimation from the finite difference: [ 3.066361    3.118813   -0.48220158]
# Iteration: 54, Parameters: [0.4427703  0.72184926 0.68417877], Controls discrepancy: 0.21702364087104797
# Gradient estimation from the finite difference: [ 1.2619793  0.1963973 -0.4194677]
# Iteration: 55, Parameters: [0.41814893 0.7162837  0.65908533], Controls discrepancy: 0.47369155287742615
# Gradient estimation from the finite difference: [-4.916191  -3.2523274  2.2149086]
# Iteration: 56, Parameters: [0.4037413  0.7119425  0.63000053], Controls discrepancy: 0.5071446895599365
# Gradient estimation from the finite difference: [-5.427599  -4.7057867  1.8054247]
# Iteration: 57, Parameters: [0.39953068 0.70905256 0.59838396], Controls discrepancy: 0.5003014206886292
# Gradient estimation from the finite difference: [-4.51982   -7.0911646  0.9691715]
# Iteration: 58, Parameters: [0.40316612 0.70804    0.5668131 ], Controls discrepancy: 0.48958441615104675
# Gradient estimation from the finite difference: [ -2.2920966  -11.314452    -0.66131353]
# Iteration: 59, Parameters: [0.4102977  0.70972776 0.54001856], Controls discrepancy: 0.4999656081199646
# Gradient estimation from the finite difference: [ -0.43928623 -15.272201    -2.552867  ]
# Iteration: 60, Parameters: [0.41752785 0.7148223  0.52320766], Controls discrepancy: 0.47039514780044556
# Gradient estimation from the finite difference: [  0.2348423 -15.390515   -3.3342838]
# Iteration: 61, Parameters: [0.42370546 0.72308046 0.5178719 ], Controls discrepancy: 0.37574049830436707
# Gradient estimation from the finite difference: [  0.16629696 -11.708736    -2.72125   ]
# Iteration: 62, Parameters: [0.42903867 0.7333783  0.521194  ], Controls discrepancy: 0.27790290117263794
# Gradient estimation from the finite difference: [-0.36001205 -5.980432   -1.3518333 ]
# Iteration: 63, Parameters: [0.434517   0.74418336 0.5283132 ], Controls discrepancy: 0.23406492173671722
# Gradient estimation from the finite difference: [-0.69245696 -0.7748604  -0.32275915]
# Iteration: 64, Parameters: [0.44071853 0.75419915 0.5357771 ], Controls discrepancy: 0.24519483745098114
# Gradient estimation from the finite difference: [-0.4300475   3.9473176   0.28148293]
# Iteration: 65, Parameters: [0.4471233  0.7623379  0.54169333], Controls discrepancy: 0.2988944947719574
# Gradient estimation from the finite difference: [0.3796816 8.766055  0.89854  ]
# Iteration: 66, Parameters: [0.45226485 0.7675627  0.5442618 ], Controls discrepancy: 0.36020421981811523
# Gradient estimation from the finite difference: [ 1.0532141 12.22074    1.4957786]
# Iteration: 67, Parameters: [0.45502704 0.76924926 0.54187244], Controls discrepancy: 0.3809494972229004
# Gradient estimation from the finite difference: [ 1.347065  12.951196   1.6415119]
# Iteration: 68, Parameters: [0.45506766 0.76750416 0.53446895], Controls discrepancy: 0.349411278963089
# Gradient estimation from the finite difference: [ 1.3807416 11.033416   1.2531877]
# Iteration: 69, Parameters: [0.45254746 0.7630979  0.52370805], Controls discrepancy: 0.2959785759449005
# Gradient estimation from the finite difference: [1.2406707  7.432997   0.55491924]
# Iteration: 70, Parameters: [0.44793665 0.7571744  0.5121237 ], Controls discrepancy: 0.2571866512298584
# Gradient estimation from the finite difference: [ 1.0669231   3.3828616  -0.22798777]
# Iteration: 71, Parameters: [0.44173142 0.7509088  0.50234324], Controls discrepancy: 0.24795910716056824
# Gradient estimation from the finite difference: [ 0.9135902  -0.35479665 -0.9958446 ]
# Iteration: 72, Parameters: [0.4343503 0.7453079 0.4967569], Controls discrepancy: 0.25903138518333435
# Gradient estimation from the finite difference: [ 0.6502867 -3.0508637 -1.5160441]
# Iteration: 73, Parameters: [0.4263911  0.74102914 0.49675295], Controls discrepancy: 0.2738301753997803
# Gradient estimation from the finite difference: [ 0.04529953 -5.019903   -1.7261505 ]
# Iteration: 74, Parameters: [0.4190708 0.7384883 0.5025721], Controls discrepancy: 0.2803240716457367
# Gradient estimation from the finite difference: [-0.7608533 -4.90278   -1.3011694]
# Iteration: 75, Parameters: [0.41391307 0.73750794 0.51228595], Controls discrepancy: 0.2819051742553711
# Gradient estimation from the finite difference: [-1.7464161  -3.69668    -0.58978796]
# Iteration: 76, Parameters: [0.41268688 0.73762804 0.52313656], Controls discrepancy: 0.28065988421440125
# Gradient estimation from the finite difference: [-2.424717   -2.5215745  -0.06228685]
# Iteration: 77, Parameters: [0.41641757 0.73843306 0.5332097 ], Controls discrepancy: 0.2703164219856262
# Gradient estimation from the finite difference: [-2.5260448  -1.6185641   0.19818544]
# Iteration: 78, Parameters: [0.42489472 0.7396152  0.54166603], Controls discrepancy: 0.2507818937301636
# Gradient estimation from the finite difference: [-1.9901991  -1.3229251   0.13709068]
# Iteration: 79, Parameters: [0.43663767 0.74106085 0.54886264], Controls discrepancy: 0.23106232285499573
# Gradient estimation from the finite difference: [-1.1463463  -0.90017915 -0.03650784]
# Iteration: 80, Parameters: [0.4496532  0.74262923 0.555529  ], Controls discrepancy: 0.2208409309387207
# Gradient estimation from the finite difference: [-0.10430813 -0.11712313 -0.26255846]
# Iteration: 81, Parameters: [0.46168944 0.7440871  0.56252754], Controls discrepancy: 0.2245795577764511
# Gradient estimation from the finite difference: [ 1.090914    1.2128055  -0.42513013]
# Iteration: 82, Parameters: [0.47034016 0.7450607  0.5704255 ], Controls discrepancy: 0.23655658960342407
# Gradient estimation from the finite difference: [ 2.103597   2.721548  -0.4248321]
# Iteration: 83, Parameters: [0.47376165 0.7451516  0.57915235], Controls discrepancy: 0.24133476614952087
# Gradient estimation from the finite difference: [ 2.4525821  3.7240982 -0.3156066]
# Iteration: 84, Parameters: [0.47165838 0.7441392  0.58824176], Controls discrepancy: 0.230646014213562
# Gradient estimation from the finite difference: [ 1.9136071   3.6491454  -0.20965934]
# Iteration: 85, Parameters: [0.4656516  0.74213773 0.59727544], Controls discrepancy: 0.21658949553966522
# Gradient estimation from the finite difference: [ 0.41112304  2.002567   -0.04440546]
# Iteration: 86, Parameters: [0.4593103  0.7397216  0.60564375], Controls discrepancy: 0.21787503361701965
# Gradient estimation from the finite difference: [-1.0290742   0.13187528  0.39488077]
# Iteration: 87, Parameters: [0.45579615 0.7374884  0.61174303], Controls discrepancy: 0.22684234380722046
# Gradient estimation from the finite difference: [-1.6234815  -0.7496774   0.71823597]
# Iteration: 88, Parameters: [0.45617348 0.7356894  0.6145327 ], Controls discrepancy: 0.23017001152038574
# Gradient estimation from the finite difference: [-1.6598403 -1.2934208  0.7763505]
# Iteration: 89, Parameters: [0.46019238 0.7344535  0.61407125], Controls discrepancy: 0.22584804892539978
# Gradient estimation from the finite difference: [-1.3099611 -1.8879771  0.5851686]
# Iteration: 90, Parameters: [0.4667651 0.7339162 0.6113775], Controls discrepancy: 0.21925491094589233
# Gradient estimation from the finite difference: [-0.69096684 -2.220422    0.22441149]
# Iteration: 91, Parameters: [0.47428635 0.7341218  0.60805285], Controls discrepancy: 0.21708527207374573
# Gradient estimation from the finite difference: [ 0.30770898 -1.6979873  -0.26077032]
# Iteration: 92, Parameters: [0.48041335 0.7348429  0.6060666 ], Controls discrepancy: 0.22290928661823273
# Gradient estimation from the finite difference: [ 1.6514957  -0.22575259 -0.6213784 ]
# Iteration: 93, Parameters: [0.4821913 0.735569  0.6067409], Controls discrepancy: 0.22602364420890808
# Gradient estimation from the finite difference: [ 2.207756    0.6979704  -0.65505505]
# Iteration: 94, Parameters: [0.47871065 0.7360045  0.6099848 ], Controls discrepancy: 0.21816407144069672
# Gradient estimation from the finite difference: [ 1.3707578   0.24154782 -0.47400594]
# Iteration: 95, Parameters: [0.47236535 0.7363217  0.61484826], Controls discrepancy: 0.21321378648281097
# Gradient estimation from the finite difference: [-0.13679266 -0.81315637  0.01400709]
# Iteration: 96, Parameters: [0.46692863 0.73687404 0.6192039 ], Controls discrepancy: 0.21715235710144043
# Gradient estimation from the finite difference: [-1.0226667  -0.95933676  0.50634146]
# Iteration: 97, Parameters: [0.4644132  0.73768985 0.62107104], Controls discrepancy: 0.22055357694625854
# Gradient estimation from the finite difference: [-1.3276935 -0.7134676  0.7016957]
# Iteration: 98, Parameters: [0.4652938  0.7386659  0.61985314], Controls discrepancy: 0.21815448999404907
# Gradient estimation from the finite difference: [-1.1575222  -0.29280782  0.5809963 ]
# Iteration: 99, Parameters: [0.46887127 0.73964894 0.6163185 ], Controls discrepancy: 0.21409490704536438
# Gradient estimation from the finite difference: [-0.33944845  0.7684529   0.18835068]
# estimated Omega parameters [output of the function times scaling]: [4.72938   0.7402826 6.123181 ]

# %%
# plots the trajectory of the Omega parameters

# Convert trajectories and discrepancies to numpy arrays for plotting
Omega_trajectory = jnp.array(Omega_trajectory)
control_discrepancies = jnp.array(control_discrepancies)

# Plot the results
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot of the Omega parameters trajectory
sc = ax.scatter(Omega_trajectory[:, 0], Omega_trajectory[:, 1], Omega_trajectory[:, 2],
                c=control_discrepancies, cmap='viridis', marker='o')

# Plot the true Omega parameters
ax.scatter(scaled_Omega_parameters[0], scaled_Omega_parameters[1], scaled_Omega_parameters[2],
           color='red', marker='x', s=100, label='Scaled $\\Omega$ Parameters')

# Plot arrows and edges
for i in range(1, len(Omega_trajectory)):
    ax.plot([Omega_trajectory[i-1, 0], Omega_trajectory[i, 0]],
            [Omega_trajectory[i-1, 1], Omega_trajectory[i, 1]],
            [Omega_trajectory[i-1, 2], Omega_trajectory[i, 2]], 'gray')
    ax.quiver(Omega_trajectory[i-1, 0], Omega_trajectory[i-1, 1], Omega_trajectory[i-1, 2],
              Omega_trajectory[i, 0] - Omega_trajectory[i-1, 0],
              Omega_trajectory[i, 1] - Omega_trajectory[i-1, 1],
              Omega_trajectory[i, 2] - Omega_trajectory[i-1, 2], color='black', arrow_length_ratio=0.1)

ax.set_xlabel('$\\gamma$')
ax.set_ylabel('$\\tau$')
ax.set_zlabel('$\\nu$')
ax.set_title('Trajectory of $\\Omega$ Parameters')
fig.colorbar(sc, ax=ax, label='Discrepancy E')

# Adjust the legend position
ax.legend(loc='upper left', bbox_to_anchor=(0, 1))

plt.show()

# %%
# verify if the results at least look similar:
estimated_Omega_parameters = Omega_parameters
print(f"obtained parameters: {estimated_Omega_parameters}")

print(f"estimated theta: {estimated_theta}")

u_star = find_u_grid(n_agents, n_steps, dt, x0, estimated_theta, estimated_Omega_parameters)
print("optimized_trajectory: from learnt coefficints")
plot_the_trajectories(u_star, x0, estimated_theta, dt, n_agents, n_steps, t, estimated_Omega_parameters)


print("previously observed trajectory ")
print(f"true beta parameters: {true_Omega_parameters}")
plot_the_trajectories(u_observed, x0, true_theta_coefficients, dt, n_agents, n_steps, t, scaled_Omega_parameters)
# Out:
# obtained parameters: [0.472938  0.7402826 0.6123181]
# estimated theta: [-0.08777742  0.          0.          0.08519293  0.          0.        ]
# optimized_trajectory: from learnt coefficints
# previously observed trajectory
# true beta parameters: [4.   0.75 5.  ]
